# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
import random
from functools import reduce
from ast import literal_eval
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

# %%
#reference: https://doi.org/10.24432/C54G67 
#terminal install required
#pip install ucimlrepo
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
df = fetch_ucirepo(id=60) 
  
# data (as pandas dataframes) 
feature = df.data.features 
target = df.data.targets 
  
# metadata 
print(df.metadata) 
  
# variable information 
print(df.variables) 

# Combine features and targets into a single DataFrame
df = pd.concat([feature, target], axis=1)

# Check for missing values in the entire DataFrame
if df.isnull().any().any():
    print("There are missing values in the DataFrame.")
else:
    print("No missing values in the DataFrame.")

# Display the DataFrame
df
# Out:
# {'uci_id': 60, 'name': 'Liver Disorders', 'repository_url': 'https://archive.ics.uci.edu/dataset/60/liver+disorders', 'data_url': 'https://archive.ics.uci.edu/static/public/60/data.csv', 'abstract': 'BUPA Medical Research Ltd. database donated by Richard S. Forsyth', 'area': 'Health and Medicine', 'tasks': ['Regression'], 'characteristics': ['Multivariate'], 'num_instances': 345, 'num_features': 5, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': [], 'target_col': ['drinks'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2016, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C54G67', 'creators': [], 'intro_paper': None, 'additional_info': {'summary': 'The first 5 variables are all blood tests which are thought to be sensitive to liver disorders that might arise from excessive alcohol consumption. Each line in the dataset constitutes the record of a single male individual.\n\nImportant note: The
# ...

# %%
print("Number of columns: ",len(df.columns))
print("Number of rows: ",df.shape[0])
print(f"Number of data points in the DataFrame: ", len(df.columns) * df.shape[0])

# Check for missing values in the entire DataFrame
if df.isnull().any().any():
    print("There are missing values in the DataFrame.")
else:
    print("No missing values in the DataFrame.")
# Out:
# Number of columns:  6
# Number of rows:  345
# Number of data points in the DataFrame:  2070
# No missing values in the DataFrame.

# %%
df.mcv.plot.hist()
plt.title('Histogram of mcv')
plt.show()

# %%
df.alkphos.plot.hist()
plt.title('Histogram of alkphos')
plt.show()

# %%
df.sgpt.plot.hist()
plt.title('Histogram of sgpt')
plt.show()

# %%
df.sgot.plot.hist()
plt.title('Histogram of sgot')
plt.show()

# %%
df.gammagt.plot.hist()
plt.title('Histogram of gammagt')
plt.show()

# %%
df.drinks.plot.hist()
plt.title('Histogram of drinks')
plt.show()

# %%
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(8, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(correlation_matrix)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix)), correlation_matrix.columns)
plt.title('Relation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='drinks', y='mcv', data=df)
plt.title('Boxplot of mcv by drinks')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='drinks', y='alkphos', data=df)
plt.title('Boxplot of alkphos by drinks')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='drinks', y='sgpt', data=df)
plt.title('Boxplot of sgpt by drinks')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='drinks', y='sgot', data=df)
plt.title('Boxplot of sgot by drinks')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='drinks', y='gammagt', data=df)
plt.title('Boxplot of gammagt by drinks')
plt.show()

# %%
# Boxplots
plt.figure(figsize=(10, 6))
sns.boxplot(x='drinks', y='mcv', data=df)
plt.title('Boxplot of mcv by drinks')
plt.show()

# %%
# Scatter plot of sgpt vs sgot
plt.scatter(df['sgpt'], df['sgot'])
plt.title('Scatter plot of sgpt vs sgot')
plt.xlabel('sgpt')
plt.ylabel('sgot')
plt.show()

# %%
# Line plot of mcv
plt.plot(df['mcv'])
plt.title('Line plot of mcv')
plt.xlabel('Index')
plt.ylabel('mcv')
plt.show()

# %%
# Pie chart of drinks
df['drinks'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of drinks')
plt.ylabel('')
plt.show()

# %%
# Area plot of sgpt and sgot
df[['sgpt', 'sgot']].plot(kind='area', alpha=0.4)
plt.title('Area plot of sgpt and sgot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()
